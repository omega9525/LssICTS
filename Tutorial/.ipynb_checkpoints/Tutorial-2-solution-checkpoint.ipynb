# %% [markdown]
# # <font size =10 color='black'> LSS Hand On: session 2 </font>

# %%
from __future__ import print_function

#####importing the necessary libraries
#To make the plots inline otherwise it will make seperate figure
# %matplotlib inline 
#for high resolution plot outputs
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pylab as pl
import fitsio as F

# %% [markdown]
# # <font size =10 color='red'> Cosmology - The Next Decade </font>
#
# # <font size=6 color='blue'> International Center for Theoretical Science , Bangalore </font>
#
# ##  <font size=3 color='black'> Author: Shadab Alam (salam@roe.ac.uk) </font>

# %% [markdown]
# # <font size=6 color='blue'> Today's Goal: Simulated galaxy catalog and Real data </font>

# %% [markdown]
# # What is Dark Matter only N-body Cosmological Simulation?
#
# Show the video on wiki and Leacy simulation video
# https://en.wikipedia.org/wiki/File:N-body_Simulation.ogv
#
#
# # Dark Matter Haloes?
#
# # Galaxies (HOD)
#
# # Simulated Galaxy Catalogue
# datafile='/Users/shock/Documents/talks/ICTS2019/Tutorial/data/HOD_cat_model-bolshoi-ICTS-1.gcat'
#
# # Correlation function
# $$ \xi(r) = \frac{DD(r)}{ RR(r)} -1 $$
#
# # Landy-Szalay Estimator
# $$\xi(r) = \frac{DD(r) - 2*DR(r) + RR(r)}{RR(r)} $$
#
# # Measure 3D clustering  in 2D space
#
# <img src="../images/measure-2D-clustering.png" alt="drawing" width="1000"/>
#
# $$\xi(r_\perp,r_\parallel) = \frac{DD((r_\perp,r_\parallel) - 2DR((r_\perp,r_\parallel) + RR((r_\perp,r_\parallel)}{RR((r_\perp,r_\parallel)} $$
#
# # Measure 2D clustering in redshift space and make plots
#
# There are several publicly available codes to measure correlation function. The goal here is not to understand how you will write such a code but rather what are the decision one need to make. Once you understand those decisions then you can download and use any of the publicly available code pretty easily.
# We will be internally using this code written by me:
# https://gitlab.com/shadaba/CorrelationFunction
#
#
# We will be using following function to do our measurement, lets try to understand its signature first and use it once to measure the correlation function of galaxies in a simulated catalogue
#
# our simulated catalogue of galaxies is in this file:
# # datafile='../data/HOD_cat_model-bolshoi-ICTS-1.gcat'

# %%
xi_dic=get_xi(datafile,randfile=randfile,rlim=[0,20,-20,20],nbins=[20,40],sampmode=1,njn=0,pbc=0,los=0,rsd=0
                  ,filetype='polartxt')
get_xi(datafile,rlim=[0,30,-30,30],nbins=[30,60],Lbox=250.0)


def get_xi(datafile,rlim=[0,20,-20,20],nbins=[30,40],Lbox=250.0,
                  POS_min=[0,0,0],sampmode=1,njn=0,pbc=1,los=1,interactive=1,plots=0,rsd=0,
                  randfile='',filetype='txt',randfactor=2,outtag='tmp'):
    
    ''' This measures the correlation function 
    sampmode= 0=rmu , 1=rpara-rperp, 2=rtheta, 
    3=log(rpar)-rperp (The range of r_perp in samplim should be entered in the log space), 
    4=log(r)-theta (The range of r in samplim should be entered in the log space)
    randfactor: number of times randoms compared to galaxies'''
    

    comm='../CorrelationFunction/Runme_Correlation.py'
    comm='%s -data %s'%(comm,datafile)
    
    if(randfile!=''):
        comm='%s -rand %s -randfactor %d'%(comm,randfile,randfactor)
        RRtype=''
    #elif(njn==0):
    #    comm='%s -rand norand -randfactor 2'%(comm)
    #    RRtype='norand'
    elif(np.int64(np.sqrt(njn))!=np.sqrt(njn)):
        print('njn must be a perfect square but it is not %d'%njn)
        sys.exit()
    else:
        comm='%s -rand generate -randfactor %d'%(comm,randfactor)
        RRtype=''
        
    comm='%s -sampmode %d -samplim %f %f %f %f'%(comm,sampmode,rlim[0],rlim[1],rlim[2],rlim[3])
    comm='%s -nbins %d %d'%(comm,nbins[0],nbins[1])
    comm='%s -pbc %d -los %d -Lbox %f -outfile tmp/PairCount/%s'%(comm,pbc,los,Lbox,outtag)
    comm='%s -RSD %d -njn %d -filetype %s -nproc 4'%(comm,rsd,njn,filetype)
    

    
    
    print(comm)
    #execute the command
    # !python $comm
    
    #convert pair count to xi
    if(False):
        pxi_comm='../CorrelationFunction/PairCountTOxi.py'
        pxi_comm='%s -sampmode %d -njn %d -Lbox %f'%(pxi_comm,sampmode,njn,Lbox)
        pxi_comm='%s -pcroot tmp/PairCount/%s'%(pxi_comm,outtag)
        pxi_comm='%s  -xi2droot tmp/XI2D/%s'%(pxi_comm,outtag)
        pxi_comm='%s -xi02root tmp/WP/%s'%(pxi_comm,outtag)
        if(RRtype!=''):
            pxi_comm='%s -RRtype %s'%(pxi_comm,RRtype)

        #pxi_comm='%s '%(pxi_comm)   
        # !python $pxi_comm
    
    
    #load result in dictionary
    xi_dic={}
    if(sampmode in [1,3]):
        xi_dic['rpar_ed']=np.linspace(rlim[2],rlim[3],nbins[1]+1)
        xi_dic['rper_ed']=np.linspace(rlim[0],rlim[1],nbins[0]+1)
        if(sampmode==3):
            xi_dic['rper_ed']=np.power(10,xi_dic['rper_ed'])
            
        xi_dic['rpar']=0.5*(xi_dic['rpar_ed'][1:]+xi_dic['rpar_ed'][:-1])
        xi_dic['rper']=0.5*(xi_dic['rper_ed'][1:]+xi_dic['rper_ed'][:-1])
        xi2d=np.loadtxt('tmp/XI2D/%s-rp-pi-NJN-%d.txt'%(outtag,njn))
        if(njn!=0):
            xi2d=xi2d[:,0]
    
        xi2d=np.transpose(xi2d.reshape(nbins[0],nbins[1]))
        xi_dic['xi2d']=np.column_stack([xi2d[:,::-1],xi2d])
        xi_dic['rper']=np.append(-xi_dic['rper'][::-1],xi_dic['rper'])
        
        #load wp
        xi_dic['wp']=np.loadtxt('tmp/WP/%s-wp-rp-pi-NJN-%d.txt'%(outtag,njn))
        
    if(sampmode ==0):
        xi_dic['r3d_ed']=np.linspace(rlim[2],rlim[3],nbins[1]+1)
        xi_dic['mu_ed']=np.linspace(rlim[0],rlim[1],nbins[0]+1)
        
        xi_dic['r3d']=0.5*(xi_dic['r3d_ed'][1:]+xi_dic['r3d_ed'][:-1])
        xi_dic['mu']=0.5*(xi_dic['mu_ed'][1:]+xi_dic['mu_ed'][:-1])
        xi2d=np.loadtxt('tmp/XI2D/%s-rmu-NJN-%d.txt'%(outtag,njn))
        if(njn!=0):
            xi2d=xi2d[:,0]
            
        xi_dic['xi2d']=np.transpose(xi2d.reshape(nbins[0],nbins[1]))
        
        #load xi0/xi2
        xi_dic['xi0']=np.loadtxt('tmp/XI02/%s-xi0-rmu-NJN-%d.txt'%(outtag,njn))
        xi_dic['xi2']=np.loadtxt('tmp/XI02/%s-xi2-rmu-NJN-%d.txt'%(outtag,njn))
        
    return xi_dic

def draw_circle(radius=1.0,color='r'):
    xx=np.linspace(0,radius,30)
    yy=np.sqrt(np.power(radius,2)-np.power(xx,2))
    
    pl.plot(xx,yy,'-',color=color)
    pl.plot(-xx,yy,'-',color=color)
    pl.plot(-xx,-yy,'-',color=color)
    pl.plot(xx,-yy,'-',color=color)
    
    return 0

# %% [markdown]
# # Explain following things:
# 1) get_xi function signature with rlims, nbins, Lbox
#      $$rlims=[r_{\perp}^{min}, r_{\perp}^{max},r_{\parallel}^{min}, r_{\parallel}^{max}]$$
#      $$nbins=[\text{number of bins in the first axis}, \text{number of bins in the second axis}] $$
#      $$L_{box}= 250$$
#
# 2) python dictionary including xi2d, rper and rpar
#
# 3) pl.imshow
#
#
# # <font size=5, color='blue'> Work 1 (10 minutes): Measure the clustering of simulation </font>
# Now write the code to measure the 2D correlation function of simulated galaxy catalogue using the function
# <font size=3, color='green'> get_xi</font>
#
# and plot the measured clustering. You should measure the clustering for rper 0-30 (Mpc/h)and rpar -30 to 30 (Mpc/h).
#
# Also draw a circle of certain radius to compare the contours with circle.
#
# # use the cells below to write and execute the code you can create new cells by clicking on the + sign on the top panel below File

# %%
#solutione to work 1 part 1
datafile='../data/HOD_cat_model-bolshoi-ICTS-1.gcat'
xi_dic=get_xi(datafile,rlim=[0,30,-30,30],nbins=[30,60],Lbox=250.0)
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 1 -samplim 0.000000 30.000000 -30.000000 30.000000 -nbins 30 60 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 0 -njn 0 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# post: (39287, 4)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 2 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 4 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 9 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 9 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rp-pi-NJN-0.txt
# outtags:  ['wp']
# written: tmp/WP/tmp-wp-rp-pi-NJN-0.txt
# ...

# %%
#solutione to work 1 part 2
drper=0.5*np.mean(xi_dic['rper'][1:]-xi_dic['rper'][:-1])
drpar=0.5*np.mean(xi_dic['rpar'][1:]-xi_dic['rpar'][:-1])

pl.figure(figsize=(15,10))
pl.pcolor(xi_dic['rper']-drper,xi_dic['rpar']-drpar,np.log10(xi_dic['xi2d']))

#add color bar
pl.colorbar().set_label(label=r'$\xi(r_\perp,r_\parallel)$',size=22,weight='bold')

#make the contour plot
pl.contour(xi_dic['rper'],xi_dic['rpar'],np.log10(xi_dic['xi2d']),colors='k')

pl.xlabel(r'$r_\parallel$',fontsize=22)
pl.ylabel(r'$r_\perp$',fontsize=22)
pl.xlim([-30,30])
pl.ylim([-30,30])

pl.axis('equal')

draw_circle(radius=13.0,color='r')
# Out:
# /tmp/ipykernel_30678/1055457292.py:6: RuntimeWarning: invalid value encountered in log10
#   pl.pcolor(xi_dic['rper']-drper,xi_dic['rpar']-drpar,np.log10(xi_dic['xi2d']))
# /tmp/ipykernel_30678/1055457292.py:9: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   pl.colorbar().set_label(label=r'$\xi(r_\perp,r_\parallel)$',size=22,weight='bold')
# /tmp/ipykernel_30678/1055457292.py:12: RuntimeWarning: invalid value encountered in log10
#   pl.contour(xi_dic['rper'],xi_dic['rpar'],np.log10(xi_dic['xi2d']),colors='k')
# 0

# %% [markdown]
# # How will the clustering look like with redshift space distortion?
#
#
# # <font size=5, color='blue'> Work 2 (10 minutes): Redshift Space correlation function </font>
# move galaxies to their redshift space position by setting rsd=1 in get_xi and measure the clustering signal again.
# Make a plot to compare this with your previous plot. Also draw a circle of radius 10 on top of the correlation function to see if this is symmetric.

# %%
#solution to work 2 part 1
datafile='../data/HOD_cat_model-bolshoi-ICTS-1.gcat'
xi_dic=get_xi(datafile,rlim=[0,30,-30,30],nbins=[30,60],Lbox=250.0,rsd=1)
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 1 -samplim 0.000000 30.000000 -30.000000 30.000000 -nbins 30 60 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 1 -njn 0 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# post: (39287, 4)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 2 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 4 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 9 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 9 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rp-pi-NJN-0.txt
# outtags:  ['wp']
# written: tmp/WP/tmp-wp-rp-pi-NJN-0.txt
# ...

# %%
#solutione to work 2 part 2
drper=0.5*np.mean(xi_dic['rper'][1:]-xi_dic['rper'][:-1])
drpar=0.5*np.mean(xi_dic['rpar'][1:]-xi_dic['rpar'][:-1])

pl.figure(figsize=(15,10))
pl.pcolor(xi_dic['rper']-drper,xi_dic['rpar']-drpar,np.log10(xi_dic['xi2d']),vmin=-2,vmax=2)

#add color bar
pl.colorbar().set_label(label=r'$\xi(r_\perp,r_\parallel)$',size=22,weight='bold')

#make the contour plot
pl.contour(xi_dic['rper'],xi_dic['rpar'],np.log10(xi_dic['xi2d']),colors='k')

pl.xlabel(r'$r_\parallel$',fontsize=22)
pl.ylabel(r'$r_\perp$',fontsize=22)
pl.xlim([-30,30])
pl.ylim([-30,30])

draw_circle(radius=13.0,color='r')
# Out:
# 0

# %% [markdown]
# # Multipole expansion
#
# <img src="../images/multipole-expansion.png" alt="drawing" width="1000"/>
#
# # Explain sampmode in get_xi and rlims. Also explain xi0 and xi2 in dictionary
#
# # <font size=5, color='blue'> Work 3 (10 minutes): Compute the multipole moments using get_xi in real and redshift space make a plot with pair seperation (r) on x-axis and either r^2 monopole or r^2 Quadruple on the y-axis</font>

# %%
#solution p
datafile='../data/HOD_cat_model-bolshoi-ICTS-1.gcat'
xi_dic_wrsd=get_xi(datafile,rlim=[0,30,0,1],nbins=[30,100],Lbox=250.0,rsd=1,sampmode=0,randfactor=2)
xi_dic_norsd=get_xi(datafile,rlim=[0,30,0,1],nbins=[30,100],Lbox=250.0,rsd=0,sampmode=0,randfactor=2)
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 0 -samplim 0.000000 30.000000 0.000000 1.000000 -nbins 30 100 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 1 -njn 0 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# post: (39287, 4)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 1 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 2 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 5 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 5 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/PairCountTOxi_utility.py:341: RuntimeWarning: divide by zero encountered in scalar divide
#   xi2d=(pcbin['DD']/pcbin[xi_estimator])-1.0
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rmu-NJN-0.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/tmp-xi0-rmu-NJN-0.txt
# written: tmp/XI02/tmp-xi2-rmu-NJN-0.txt
# ...../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 0 -samplim 0.000000 30.000000 0.000000 1.000000 -nbins 30 100 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 0 -njn 0 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# post: (39287, 4)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 1 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 2 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 6 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 6 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/PairCountTOxi_utility.py:341: RuntimeWarning: divide by zero encountered in scalar divide
#   xi2d=(pcbin['DD']/pcbin[xi_estimator])-1.0
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rmu-NJN-0.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/tmp-xi0-rmu-NJN-0.txt
# written: tmp/XI02/tmp-xi2-rmu-NJN-0.txt
# ...

# %%
tlab=['real space','rsd space']
for ii,xi_dic in enumerate([xi_dic_norsd,xi_dic_wrsd]):
    pl.figure(1)
    pl.plot(xi_dic['xi0'][:,0],np.power(xi_dic['xi0'][:,0],0)*xi_dic['xi0'][:,1],'o-',label=tlab[ii])
    pl.legend()
    pl.xscale('log')
    pl.yscale('log')
    pl.title('Monopole',fontsize=22)
    pl.xlabel('r (Mpc/h)',fontsize=22)
    pl.ylabel(r'$\xi_0(r)$',fontsize=22)
    
    pl.figure(2)
    pl.plot(xi_dic['xi2'][:,0],np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,1],'o-',label=tlab[ii])
    pl.legend()
    pl.title('Quadruple',fontsize=22)
    pl.xlabel('r (Mpc/h)',fontsize=22)
    pl.ylabel(r'$r^2 \xi_2(r)$',fontsize=22)

# %% [markdown]
# # Estimation of error:
# There are several methods to quanitfy the error on clustering signal. Typically the simplest and most accurate but computationally expensive methods uses N-body simulations. The computationally least expensive but complex and approximate method use perturbation theory and most popular method uses approximate mocks which are fast simulation using perturbation theory methods.
#
# We can also estimate the error from data. Two such methods widely used are know as "Jakknife" and "Bootstrap".
# Both of these methods can be shown to work exactly right with known biases if the assumptions are satisfied.
# But in comoslogical analysis those assumptions are not entirely satisfied and hence these methods can over or under estimate error depending on the situation.
#
# # Jackknife errors
#
# <img src="../images/jackknife-resampling.png" alt="drawing" width="600"/>
#
# $$Var(s_i)= \frac{(N_{jn}-1)}{N_{jn}}  \sum_{jn=0}^{jn<njn} (s_{jn,i}- \bar{s_i}) ^2$$
#
#
#
# # explain pl.errorbar(x,y,yerr) and njn in get_xi including modified output xi0,xi2
#
# # <font size=5, color='blue'> Work 4 (10 minutes): Compute the multipole moments using get_xi in real and redshift space make a plot with pair seperation (r) on x-axis and either r^2 monopole or r^2 Quadruple on the y-axis</font>

# %%
datafile='../data/HOD_cat_model-bolshoi-ICTS-1.gcat'
xi_dic_wrsd=get_xi(datafile,rlim=[0,30,0,1],nbins=[30,100],Lbox=250.0,rsd=1,sampmode=0,njn=25)
xi_dic_norsd=get_xi(datafile,rlim=[0,30,0,1],nbins=[30,100],Lbox=250.0,rsd=0,sampmode=0,njn=25)
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 0 -samplim 0.000000 30.000000 0.000000 1.000000 -nbins 30 100 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 1 -njn 25 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# Using 2d Jacknife: 5 5
# Added pbc jn reg: 0.0 24.0 0.0 24.0
# post: (39287, 5)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 1 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 2 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 6 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 6 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/PairCountTOxi_utility.py:341: RuntimeWarning: divide by zero encountered in scalar divide
#   xi2d=(pcbin['DD']/pcbin[xi_estimator])-1.0
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# written:  tmp/XI2D/tmp-rmu-NJN-25.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/tmp-xi0-rmu-NJN-25.txt
# written: tmp/XI02/tmp-xi2-rmu-NJN-25.txt
# ...../CorrelationFunction/Runme_Correlation.py -data ../data/HOD_cat_model-bolshoi-ICTS-1.gcat -rand generate -randfactor 2 -sampmode 0 -samplim 0.000000 30.000000 0.000000 1.000000 -nbins 30 100 -pbc 1 -los 1 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 0 -njn 25 -filetype txt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/HOD_cat_model-bolshoi-ICTS-1.gcat (39287, 9)
# random file not given, Generating internal 78574 random
# (39287, 4) (78574, 4)
# Using 2d Jacknife: 5 5
# Added pbc jn reg: 0.0 24.0 0.0 24.0
# post: (39287, 5)
#      39287 galaxies from ../data/HOD_cat_model-bolshoi-ICTS-1.gcat
#      78574 randoms from generate
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 88, because ndata_min=39287
#
# Workind on DD (. every 100k points):
#
# Finished DD in 1 sec with 4 process and 39287 39287 particles, max scale    30.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 2 sec with 4 process and 39287 78574 particles, max scale    30.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 5 sec with 4 process and 78574 78574 particles, max scale    30.0000
#
# Finished job in 5 sec with 4 process and nrand 78574 ,max scale    30.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/PairCountTOxi_utility.py:341: RuntimeWarning: divide by zero encountered in scalar divide
#   xi2d=(pcbin['DD']/pcbin[xi_estimator])-1.0
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# written:  tmp/XI2D/tmp-rmu-NJN-25.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/tmp-xi0-rmu-NJN-25.txt
# written: tmp/XI02/tmp-xi2-rmu-NJN-25.txt
# ...

# %%
tlab=['real space','rsd space']
for ii,xi_dic in enumerate([xi_dic_norsd,xi_dic_wrsd]):
    pl.figure(1)
    pl.errorbar(xi_dic['xi0'][:,0],np.power(xi_dic['xi0'][:,0],0)*xi_dic['xi0'][:,1],
               yerr=np.power(xi_dic['xi0'][:,0],0)*xi_dic['xi0'][:,2],marker='o',label=tlab[ii])
    pl.legend()
    pl.xscale('log')
    pl.yscale('log')
    pl.title('Monopole',fontsize=22)
    pl.xlabel('r (Mpc/h)',fontsize=22)
    pl.ylabel(r'$\xi_0(r)$',fontsize=22)
    
    pl.figure(2)
    
    pl.errorbar(xi_dic['xi2'][:,0],np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,1],
               yerr=np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,2],marker='o',label=tlab[ii])
    
    pl.legend()
    pl.title('Quadruple',fontsize=22)
    pl.xlabel('r (Mpc/h)',fontsize=22)
    pl.ylabel(r'$r^2 \xi_2(r)$',fontsize=22)

# %% [markdown]
# # Constructing a Jackknife covariance matrix
#
#
# # Variance:
# $$Var(s_i)= \frac{(N_{jn}-1)}{N_{jn}}  \sum_{jn=0}^{jn<njn} (s_{jn,i}- \bar{s_i}) ^2$$
#
# # Covariance matrix
# $$C_{i,j}= \frac{(N_{jn}-1)}{N_{jn}} \sum_{jn=0}^{jn<njn} (s_{jn,i}- \bar{s_i}) \sum_{jn=0}^{jn<njn} (s_{jn,j}- \bar{s_j})$$
#
# # Correlation matrix
# $$Corr_{i,j}=\frac{C_{i,j}}{\sqrt{C_{i,i}C_{j,j}}}$$
#
# # Example covariance matrix of monopole

# %%
#covariance of the monopole
njn=xi_dic_wrsd['xi0'].shape[1]-4

covxi0=(njn-1)*np.cov(xi_dic_wrsd['xi0'][:,4:])

pl.figure(figsize=(8,8))
pl.imshow(covxi0)
pl.colorbar()
pl.title('covariance matrix of monopole')

corrxi0=np.copy(covxi0)
for ii in range(0,covxi0.shape[0]):
    for jj in range(0,covxi0.shape[1]):
        corrxi0[ii,jj]=covxi0[ii,jj]/(np.sqrt(covxi0[ii,ii])*np.sqrt(covxi0[jj,jj]))

pl.figure(figsize=(8,8))
pl.imshow(corrxi0,vmin=-1,vmax=1,cmap='seismic')
pl.colorbar()       
pl.title('correlation matrix of monopole')
# Out:
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Text(0.5, 1.0, 'correlation matrix of monopole')

# %% [markdown]
# # <font size=5, color='blue'> Work 5 (5 minutes): Compute the covariance and correlation matrix of Quadruple moment of the correlation function and make plots</font>

# %%
#covariance of the Quadrupole
njn=xi_dic_wrsd['xi2'].shape[1]-4

covxi2=(njn-1)*np.cov(xi_dic_wrsd['xi2'][:,4:])

pl.figure(figsize=(8,8))
pl.imshow(covxi2)
pl.colorbar()
pl.title('covariance matrix of Quadrupole')

corrxi2=np.copy(covxi2)
for ii in range(0,covxi2.shape[0]):
    for jj in range(0,covxi2.shape[1]):
        corrxi2[ii,jj]=covxi2[ii,jj]/(np.sqrt(covxi2[ii,ii])*np.sqrt(covxi2[jj,jj]))

pl.figure(figsize=(8,8))
pl.imshow(corrxi2,vmin=-1,vmax=1,cmap='seismic')
pl.colorbar()       
pl.title('correlation matrix of Quadrupole')
# Out:
# Text(0.5, 1.0, 'correlation matrix of Quadrupole')

# %% [markdown]
# # Combined and cross covariance of $\xi_0$ and $\xi_2$
#
#
# # <font size=5, color='blue'> Work 6 (10 minutes): Compute the combined covariance and correlation matrix of $\xi_0$ and $\xi_2$ and make plots</font>
#
# # Hint: use np.row_stack function to make combined array

# %%
#Combined covariance matrix
njn=xi_dic_wrsd['xi2'].shape[1]-4

xi02=np.row_stack([xi_dic_wrsd['xi0'][:,4:],xi_dic_wrsd['xi2'][:,4:]])
covxi2=(njn-1)*np.cov(xi02)

pl.figure(figsize=(8,8))
pl.imshow(covxi2)
pl.colorbar()
pl.title('covariance matrix of combined')

corrxi2=np.copy(covxi2)
for ii in range(0,covxi2.shape[0]):
    for jj in range(0,covxi2.shape[1]):
        corrxi2[ii,jj]=covxi2[ii,jj]/(np.sqrt(covxi2[ii,ii])*np.sqrt(covxi2[jj,jj]))

pl.figure(figsize=(8,8))
pl.imshow(corrxi2,vmin=-1,vmax=1,cmap='seismic')
pl.colorbar()       
pl.title('correlation matrix of combined')
# Out:
# Text(0.5, 1.0, 'correlation matrix of combined')

# %% [markdown]
# # Look at real data from Sloan Digital Sky Survey (SDSS)
#
# #  <font size=5, color='green'> datafile= '../data/LOWZ-all-galaxy.txt' </font>
# #  <font size=5, color='green'> randomfile= '../data/LOWZ-all-random.txt' </font>
#
#
# # <font size=5, color='blue'> Exploration: (5 minutes) </font>
#
# The file has three columns RA,DEC and redshift.
# load the file using "np.loadtxt" which will give you a numpy array and explore the data by making plots and distribution of data.

# %%
import numpy as np
#to load the data
datafile= '../data/LOWZ-all-galaxy.txt'
data=np.loadtxt(datafile)


pl.figure(1)
pl.plot(data[:,0],data[:,1],'.')
pl.xlabel('RA',fontsize=24)
pl.xlabel('DEC',fontsize=24)


pl.figure(3)
pl.hist(data[:,2],bins=100,histtype='step')
pl.xlabel('Z (redshift)',fontsize=24)
pl.title('histogram of redshift')
# Out:
# Text(0.5, 1.0, 'histogram of redshift')

# %% [markdown]
# # Explain following inputs of get_xi
#
# randfile='',sampmode=1, pbc=0, njn=0, los=0, rsd=0, filetype='polartxt'
#
# # <font size=5, color='blue'> Work 7 (10 minutes): Now compute the clustering of data with rper=0,20 and rpar=-20,20 and make a 2d plot with axis as rper and rpar and the color axis as logarithm of the correlation function also plot contours </font>
#
# # Hint: use pl.imshow and pl.contour for plotting

# %%
datafile='../data/LOWZ-all-galaxy.txt'
randfile='../data/LOWZ-all-random.txt'
xi_dic=get_xi(datafile,randfile=randfile,rlim=[0,20,-20,20],nbins=[20,40],sampmode=1,njn=0,pbc=0,los=0,rsd=0
                  ,filetype='polartxt')
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/LOWZ-all-galaxy.txt -rand ../data/LOWZ-all-random.txt -randfactor 2 -sampmode 1 -samplim 0.000000 20.000000 -20.000000 20.000000 -nbins 20 40 -pbc 0 -los 0 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 0 -njn 0 -filetype polartxt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/LOWZ-all-galaxy.txt (317780, 4)
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# nrand selected:  635560 635560
# (317780, 4) (635560, 4)
# post: (317780, 4)
#     317780 galaxies from ../data/LOWZ-all-galaxy.txt
#     635560 randoms from ../data/LOWZ-all-random.txt
#
# Time:0 sec
#
# Prepared data and random:0 sec
# Updating nhocells to : 175, because ndata_min=317780
#
# Workind on DD (. every 100k points):
#
# Finished DD in 2 sec with 4 process and 317780 317780 particles, max scale    20.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 6 sec with 4 process and 317780 635560 particles, max scale    20.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 20 sec with 4 process and 635560 635560 particles, max scale    20.0000
#
# Finished job in 20 sec with 4 process and nrand 635560 ,max scale    20.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rp-pi-NJN-0.txt
# outtags:  ['wp']
# written: tmp/WP/tmp-wp-rp-pi-NJN-0.txt
# ...............

# %%
#solutione to work 1 part 2
drper=0.5*np.mean(xi_dic['rper'][1:]-xi_dic['rper'][:-1])
drpar=0.5*np.mean(xi_dic['rpar'][1:]-xi_dic['rpar'][:-1])

pl.figure(figsize=(15,10))
pl.pcolor(xi_dic['rper']-drper,xi_dic['rpar']-drpar,np.log10(xi_dic['xi2d']))

#add color bar
pl.colorbar().set_label(label=r'$\xi(r_\perp,r_\parallel)$',size=22,weight='bold')

#make the contour plot
pl.contour(xi_dic['rper'],xi_dic['rpar'],np.log10(xi_dic['xi2d']),colors='k')

pl.xlabel(r'$r_\parallel$',fontsize=22)
pl.ylabel(r'$r_\perp$',fontsize=22)
pl.xlim([-20,20])
pl.ylim([-20,20])
# Out:
# (-20.0, 20.0)

# %% [markdown]
# # <font size=5, color='blue'> Work 8 (10 minutes): Now compute monopole and quadruple moment of the correlation function and make plots from data. </font>
#
# # Hint: you need to think about sampling axis and limits

# %%
#datafile='../data/GAMA-G15-galaxy.txt'
#randfile='../data/GAMA-G15-random.txt'
xi_dic=get_xi(datafile,randfile=randfile,rlim=[0,40,0,1],nbins=[20,60],sampmode=0,njn=0,pbc=0,los=0,rsd=0
                  ,filetype='polartxt')
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/LOWZ-all-galaxy.txt -rand ../data/LOWZ-all-random.txt -randfactor 2 -sampmode 0 -samplim 0.000000 40.000000 0.000000 1.000000 -nbins 20 60 -pbc 0 -los 0 -Lbox 250.000000 -outfile tmp/PairCount/tmp -RSD 0 -njn 0 -filetype polartxt -nproc 4
# outfile : tmp/PairCount/tmp
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/LOWZ-all-galaxy.txt (317780, 4)
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# nrand selected:  635560 635560
# (317780, 4) (635560, 4)
# post: (317780, 4)
#     317780 galaxies from ../data/LOWZ-all-galaxy.txt
#     635560 randoms from ../data/LOWZ-all-random.txt
#
# Time:1 sec
#
# Prepared data and random:1 sec
# Updating nhocells to : 175, because ndata_min=317780
#
# Workind on DD (. every 100k points):
#
# Finished DD in 3 sec with 4 process and 317780 317780 particles, max scale    40.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 12 sec with 4 process and 317780 635560 particles, max scale    40.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 35 sec with 4 process and 635560 635560 particles, max scale    40.0000
#
# Finished job in 35 sec with 4 process and nrand 635560 ,max scale    40.0000
# assuming xitype: auto RRtype=
# RRtype:
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nc/Softwares/anaconda3/envs/iagrg/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# written:  tmp/XI2D/tmp-rmu-NJN-0.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/tmp-xi0-rmu-NJN-0.txt
# written: tmp/XI02/tmp-xi2-rmu-NJN-0.txt
# ...............

# %%
pl.plot(xi_dic['xi0'][:,0],np.power(xi_dic['xi0'][:,0],0)*xi_dic['xi0'][:,1],'o-')
pl.xscale('log')
pl.yscale('log')
    
pl.figure(2)
pl.plot(xi_dic['xi2'][:,0],np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,1],'o-')

# %% [markdown]
# # <font size=5, color='blue'> Work 9: Now compute the jackknife errors of the multipoles for data. </font>
#
# # For the polar file which is how real data is you need to create files with five columns RA,DEC,Z,weight,jackknife number and then rerun the analysis

# %%
datafile='../data/LOWZ-all-galaxy.txt'
randfile='../data/LOWZ-all-random.txt'

rand=np.loadtxt(randfile)

# %%
pl.figure(figsize=(10,10))
pl.plot(rand[:,0],rand[:,1],'.')
pl.xlabel('RA',fontsize=22)
pl.ylabel('DEC',fontsize=22)
pl.title('SDSS LOWZ sample')

pl.figure()
hh=pl.hist(rand[:,2],bins=25)
pl.xlabel('Redshift',fontsize=22)
pl.ylabel('histogram')
# Out:
# Text(0, 0.5, 'histogram')

# %% [markdown]
# # Define the Jackknife partition

# %%
def execute_jn_assignment(datafile,randfilen,njack_RA=10,njack_DEC=10,Zlimit=[0,0],
                          odir='../data/JN_regions/LOWZ'):
    comm_exec='../CorrelationFunction/Jacknife_region_2D_keys.py'

    comm='%s -r1 %s -NjackRA %d -NjackDEC %d'%(comm_exec,randfile,njack_RA,njack_DEC)
    comm=comm+' -ax1 RA -ax2 DEC -ax3 Z -z1 %6.4f -z2 %6.4f'%(Zlimit[0],Zlimit[1])
    comm=comm+' -odir %s'%(odir)
    
    print(comm)
    # !python $comm
    
    return

#This code writes partition file for jacknife partition
#Below: this will be the final partition file
#../data/JN_regions/LOWZ-zlim-0.1-0.45-Border_RA-DEC_JN-10-10_v1.txt

execute_jn_assignment(datafile,randfile,njack_RA=10,njack_DEC=10,Zlimit=[0.1,0.45])
# Out:
# ../CorrelationFunction/Jacknife_region_2D_keys.py -r1 ../data/LOWZ-all-random.txt -NjackRA 10 -NjackDEC 10 -ax1 RA -ax2 DEC -ax3 Z -z1 0.1000 -z2 0.4500 -odir ../data/JN_regions/LOWZ
# time now: 11:58:51
# argumenst:  Namespace(ax1='RA', ax2='DEC', ax3='Z', add_sel='', NjackRA=10, NjackDEC=10, Ngrid=10240, d1='None', d2='None', r1='../data/LOWZ-all-random.txt', r2='fits', refiney=2, refinez=4, z1=0.1, z2=0.45, odir='../data/JN_regions/LOWZ', version='vv', pixselfile='', tag='', RAcut=[-1000, -1000], DECcut=[-1000, -1000])
# using redshift cut:  [0.1, 0.45]
# using extension: _JN-10-10_v1
# reading : ../data/LOWZ-all-random.txt
# Assuming RA,DEC,Z as columns and res ignored: found 635560 rows
# size of random array: (576412, 3)
# size of random array: (576412, 3)
# loaded randoms ,time now: 11:58:52
# ax1_plim:  [0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100]
# ax2_plim:  [0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100]
# Number of randoms (total)=  576412
# Number of Jacknife regions= 100
# Number of randoms per regions= 5764.12
# setup done, partition begin, time now: 11:58:52
#    region  low_x         high_x        Ngal
# xborder: 0 111.923268 134.4061218 57641.2
# xborder: 1 134.4061218 147.56759399999999 57641.2
# xborder: 2 147.56759399999999 160.2868513 57641.2
# xborder: 3 160.2868513 172.89516740000002 57641.2
# xborder: 4 172.89516740000002 185.26156450000002 57641.2
# xborder: 5 185.26156450000002 198.5296182 57641.2
# xborder: 6 198.5296182 211.01085379999998 57641.2
# xborder: 7 211.01085379999998 224.08311840000002 57641.2
# xborder: 8 224.08311840000002 240.72517050000002 57641.2
# xborder: 9 240.72517050000002 263.812259 57641.2
# yregion xregion low_y         high_y       Nreg
# ybord: 0 0 -0.778775 6.2530052000000005 5764.12
# ybord: 1 0 6.2530052000000005 10.645716 5764.12
# ybord: 2 0 10.645716 14.6395736 5764.12
# ybord: 3 0 14.6395736 18.101122600000004 5764.12
# ybord: 4 0 18.101122600000004 21.576925 5764.12
# ybord: 5 0 21.576925 24.9234006 5764.12
# ybord: 6 0 24.9234006 28.3997824 5764.12
# ybord: 7 0 28.3997824 33.094189400000005 5764.12
# ybord: 8 0 33.094189400000005 47.2327775 5764.12
# ybord: 9 0 47.2327775 64.783779 5764.12
# ybord: 10 1 1.194501 7.911475 5764.12
# ybord: 11 1 7.911475 12.76223 5764.12
# ybord: 12 1 12.76223 17.72238 5764.12
# ybord: 13 1 17.72238 22.693436 5764.12
# ybord: 14 1 22.693436 28.360405 5764.12
# ybord: 15 1 28.360405 33.876255 5764.12
# ybord: 16 1 33.876255 40.300751 5764.12
# ybord: 17 1 40.300751 47.879852 5764.12
# ybord: 18 1 47.879852 55.611708 5764.12
# ybord: 19 1 55.611708 65.510161 5764.12
# ybord: 20 2 1.168225 7.072448 5764.12
# ybord: 21 2 7.072448 12.133988 5764.12
# ybord: 22 2 12.133988 17.280077 5764.12
# ybord: 23 2 17.280077 22.53863 5764.12
# ybord: 24 2 22.53863 28.093027 5764.12
# ybord: 25 2 28.093027 33.763033 5764.12
# ybord: 26 2 33.763033 39.972476 5764.12
# ybord: 27 2 39.972476 46.751402 5764.12
# ybord: 28 2 46.751402 54.647274 5764.12
# ybord: 29 2 54.647274 66.762793 5764.12
# ybord: 30 3 1.09113 7.362144 5764.12
# ybord: 31 3 7.362144 12.578473 5764.12
# ybord: 32 3 12.578473 17.806352 5764.12
# ybord: 33 3 17.806352 23.213965 5764.12
# ybord: 34 3 23.213965 28.764037 5764.12
# ybord: 35 3 28.764037 34.633657 5764.12
# ybord: 36 3 34.633657 40.886902 5764.12
# ybord: 37 3 40.886902 47.822641 5764.12
# ybord: 38 3 47.822641 55.883198 5764.12
# ybord: 39 3 55.883198 67.984267 5764.12
# ybord: 40 4 1.100027 6.85705 5764.12
# ybord: 41 4 6.85705 12.031437 5764.12
# ybord: 42 4 12.031437 17.587256 5764.12
# ybord: 43 4 17.587256 23.239743 5764.12
# ybord: 44 4 23.239743 29.015526 5764.12
# ybord: 45 4 29.015526 35.038275 5764.12
# ybord: 46 4 35.038275 41.559686 5764.12
# ybord: 47 4 41.559686 48.677523 5764.12
# ybord: 48 4 48.677523 57.385553 5764.12
# ybord: 49 4 57.385553 68.741175 5764.12
# ybord: 50 5 -3.609526 5.206959 5764.12
# ybord: 51 5 5.206959 10.104344 5764.12
# ybord: 52 5 10.104344 14.984788 5764.12
# ybord: 53 5 14.984788 19.866941 5764.12
# ybord: 54 5 19.866941 25.006113 5764.12
# ybord: 55 5 25.006113 30.353803 5764.12
# ybord: 56 5 30.353803 43.048577 5764.12
# ybord: 57 5 43.048577 50.0893 5764.12
# ybord: 58 5 50.0893 57.910336 5764.12
# ybord: 59 5 57.910336 68.744036 5764.12
# ybord: 60 6 -3.606802 1.549489 5764.12
# ybord: 61 6 1.549489 6.697909 5764.12
# ybord: 62 6 6.697909 11.910433 5764.12
# ybord: 63 6 11.910433 17.087427 5764.12
# ybord: 64 6 17.087427 22.50312 5764.12
# ybord: 65 6 22.50312 28.25854 5764.12
# ybord: 66 6 28.25854 41.29772 5764.12
# ybord: 67 6 41.29772 48.38496 5764.12
# ybord: 68 6 48.38496 56.552429 5764.12
# ybord: 69 6 56.552429 67.642375 5764.12
# ybord: 70 7 -3.365951 1.619639 5764.12
# ybord: 71 7 1.619639 6.722022 5764.12
# ybord: 72 7 6.722022 11.65133 5764.12
# ybord: 73 7 11.65133 16.559848 5764.12
# ybord: 74 7 16.559848 21.785594 5764.12
# ybord: 75 7 21.785594 27.104475 5764.12
# ybord: 76 7 27.104475 39.896204 5764.12
# ybord: 77 7 39.896204 47.399339 5764.12
# ybord: 78 7 47.399339 55.104233 5764.12
# ybord: 79 7 55.104233 66.484631 5764.12
# ybord: 80 8 -2.892561 2.844917 5764.12
# ybord: 81 8 2.844917 7.112072 5764.12
# ybord: 82 8 7.112072 10.987301 5764.12
# ybord: 83 8 10.987301 15.08694 5764.12
# ybord: 84 8 15.08694 31.84542 5764.12
# ybord: 85 8 31.84542 36.865409 5764.12
# ybord: 86 8 36.865409 42.52901 5764.12
# ybord: 87 8 42.52901 48.042186 5764.12
# ybord: 88 8 48.042186 54.009503 5764.12
# ybord: 89 8 54.009503 63.28216 5764.12
# ybord: 90 9 2.894848 14.04931 5764.12
# ybord: 91 9 14.04931 19.483003 5764.12
# ybord: 92 9 19.483003 24.351787 5764.12
# ybord: 93 9 24.351787 27.71415 5764.12
# ybord: 94 9 27.71415 31.226969 5764.12
# ybord: 95 9 31.226969 34.587759 5764.12
# ybord: 96 9 34.587759 38.454452 5764.12
# ybord: 97 9 38.454452 42.833563 5764.12
# ybord: 98 9 42.833563 48.573711 5764.12
# ybord: 99 9 48.573711 61.920268 5764.12
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/Tutorial/../CorrelationFunction/Jacknife_region_2D_keys.py:454: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   pl.show()
#
#
# ***files read:***
# ../data/LOWZ-all-random.txt
#
#
# ***files written:***
# ../data/JN_regions/LOWZ-zlim-0.1-0.45-Border_RA_JN-10-10_v1.txt
# ../data/JN_regions/LOWZ-zlim-0.1-0.45-Border_RA-DEC_JN-10-10_v1.txt
#
# ***files plots:***
# ../data/JN_regions/LOWZ-zlim-0.1-0.45-RA-DEC-2D_JN-10-10_v1.png

# %% [markdown]
# # Look at the partition file
# - The first column is jackknife number which goes from 0 to some maximum value which is njn
# - The next to columns are the lower limit of RA and DEC for each region
# - The 3rd and 4th columns are the upper limit of RA and DEC for each region
# - The rest of the column shows the number of random in each partiton
#
# The logic used here is that we would want each partiton to have equla weight and randoms follows our selection function and hence this allows us to devide the sky wrighted by our selection function

# %%
# !cat ../data/JN_regions/LOWZ-zlim-0.1-0.45-Border_RA-DEC_JN-10-10_v1.txt
# Out:
# #partition in RA-DEC-plane Njack=(  10,  10)
# #RAbuf=       0.0000
# #RAcut= -1000 1000
# #No.  RAlow  DEClow  RAup DECup  Nrandom
#   0      111.92327       -0.77877      134.40612        6.25301       5764
#   1      111.92327        6.25301      134.40612       10.64572       5764
#   2      111.92327       10.64572      134.40612       14.63957       5764
#   3      111.92327       14.63957      134.40612       18.10112       5764
#   4      111.92327       18.10112      134.40612       21.57692       5764
#   5      111.92327       21.57692      134.40612       24.92340       5764
#   6      111.92327       24.92340      134.40612       28.39978       5764
#   7      111.92327       28.39978      134.40612       33.09419       5764
#   8      111.92327       33.09419      134.40612       47.23278       5764
#   9      111.92327       47.23278      134.40612       64.78378       5764
#  10      134.40612        1.19450      147.56759        7.91148       5764
#  11      134.40612        7.91148      147.56759       12.76223       5764
#  12      134.40612       12.76223      147.56759       17.72238       5764
#  13      134.40612       17.72238      147.56759       22.69344       5764
#  14      134.40612       22.69344      147.56759       28.36041       5764
#  15      134.40612       28.36041      147.56759       33.87626       5764
#  16      134.40612       33.87626      147.56759       40.30075       5764
#  17      134.40612       40.30075      147.56759       47.87985       5764
#  18      134.40612       47.87985      147.56759       55.61171       5764
#  19      134.40612       55.61171      147.56759       65.51016       5764
#  20      147.56759        1.16823      160.28685        7.07245       5764
#  21      147.56759        7.07245      160.28685       12.13399       5764
#  22      147.56759       12.13399      160.28685       17.28008       5764
#  23      147.56759       17.28008      160.28685       22.53863       5764
#  24      147.56759       22.53863      160.28685       28.09303       5764
#  25      147.56759       28.09303      160.28685       33.76303       5764
#  26      147.56759       33.76303      160.28685       39.97248       5764
#  27      147.56759       39.97248      160.28685       46.75140       5764
#  28      147.56759       46.75140      160.28685       54.64727       5764
#  29      147.56759       54.64727      160.28685       66.76279       5764
#  30      160.28685        1.09113      172.89517        7.36214       5764
#  31      160.28685        7.36214      172.89517       12.57847       5764
#  32      160.28685       12.57847      172.89517       17.80635       5764
#  33      160.28685       17.80635      172.89517       23.21397       5764
#  34      160.28685       23.21397      172.89517       28.76404       5764
#  35      160.28685       28.76404      172.89517       34.63366       5764
#  36      160.28685       34.63366      172.89517       40.88690       5764
#  37      160.28685       40.88690      172.89517       47.82264       5764
#  38      160.28685       47.82264      172.89517       55.88320       5764
#  39      160.28685       55.88320      172.89517       67.98427       5764
#  40      172.89517        1.10003      185.26156        6.85705       5764
#  41      172.89517        6.85705      185.26156       12.03144       5764
#  42      172.89517       12.03144      185.26156       17.58726       5764
#  43      172.89517       17.58726      185.26156       23.23974       5764
#  44      172.89517       23.23974      185.26156       29.01553       5764
#  45      172.89517       29.01553      185.26156       35.03827       5764
#  46      172.89517       35.03827      185.26156       41.55969       5764
#  47      172.89517       41.55969      185.26156       48.67752       5764
#  48      172.89517       48.67752      185.26156       57.38555       5764
#  49      172.89517       57.38555      185.26156       68.74117       5764
#  50      185.26156       -3.60953      198.52962        5.20696       5764
#  51      185.26156        5.20696      198.52962       10.10434       5764
#  52      185.26156       10.10434      198.52962       14.98479       5764
#  53      185.26156       14.98479      198.52962       19.86694       5764
#  54      185.26156       19.86694      198.52962       25.00611       5764
#  55      185.26156       25.00611      198.52962       30.35380       5764
#  56      185.26156       30.35380      198.52962       43.04858       5764
#  57      185.26156       43.04858      198.52962       50.08930       5764
#  58      185.26156       50.08930      198.52962       57.91034       5764
#  59      185.26156       57.91034      198.52962       68.74404       5764
#  60      198.52962       -3.60680      211.01085        1.54949       5764
#  61      198.52962        1.54949      211.01085        6.69791       5764
#  62      198.52962        6.69791      211.01085       11.91043       5764
#  63      198.52962       11.91043      211.01085       17.08743       5764
#  64      198.52962       17.08743      211.01085       22.50312       5764
#  65      198.52962       22.50312      211.01085       28.25854       5764
#  66      198.52962       28.25854      211.01085       41.29772       5764
#  67      198.52962       41.29772      211.01085       48.38496       5764
#  68      198.52962       48.38496      211.01085       56.55243       5764
#  69      198.52962       56.55243      211.01085       67.64238       5764
#  70      211.01085       -3.36595      224.08312        1.61964       5764
#  71      211.01085        1.61964      224.08312        6.72202       5764
#  72      211.01085        6.72202      224.08312       11.65133       5764
#  73      211.01085       11.65133      224.08312       16.55985       5764
#  74      211.01085       16.55985      224.08312       21.78559       5764
#  75      211.01085       21.78559      224.08312       27.10448       5764
#  76      211.01085       27.10448      224.08312       39.89620       5764
#  77      211.01085       39.89620      224.08312       47.39934       5764
#  78      211.01085       47.39934      224.08312       55.10423       5764
#  79      211.01085       55.10423      224.08312       66.48463       5764
#  80      224.08312       -2.89256      240.72517        2.84492       5764
#  81      224.08312        2.84492      240.72517        7.11207       5764
#  82      224.08312        7.11207      240.72517       10.98730       5764
#  83      224.08312       10.98730      240.72517       15.08694       5764
#  84      224.08312       15.08694      240.72517       31.84542       5764
#  85      224.08312       31.84542      240.72517       36.86541       5764
#  86      224.08312       36.86541      240.72517       42.52901       5764
#  87      224.08312       42.52901      240.72517       48.04219       5764
#  88      224.08312       48.04219      240.72517       54.00950       5764
#  89      224.08312       54.00950      240.72517       63.28216       5764
#  90      240.72517        2.89485      263.81226       14.04931       5764
#  91      240.72517       14.04931      263.81226       19.48300       5764
#  92      240.72517       19.48300      263.81226       24.35179       5764
#  93      240.72517       24.35179      263.81226       27.71415       5764
#  94      240.72517       27.71415      263.81226       31.22697       5764
#  95      240.72517       31.22697      263.81226       34.58776       5764
#  96      240.72517       34.58776      263.81226       38.45445       5764
#  97      240.72517       38.45445      263.81226       42.83356       5764
#  98      240.72517       42.83356      263.81226       48.57371       5764
#  99      240.72517       48.57371      263.81226       61.92027       5764

# %% [markdown]
# # Now we need to assign the jacknife region to our data and random file and create a new file

# %%
# Load the util library for jackknife assignment
import sys
sys.path.insert(0,'../CorrelationFunction/')
import util as util

# %%
#The reg_file is the region file created in the previous step which needs to be provided
reg_file='../data/JN_regions/LOWZ-zlim-0.1-0.45-Border_RA-DEC_JN-10-10_v1.txt'

# %%
# assign Jacknife region to data and random and write to new file
def assign_jn(datafile,randfile,reg_file):
    
    res_dic={}
    file_dic={'data':datafile,'rand':randfile}
    for tt,tkey in enumerate(file_dic.keys()):
        res_dic[tkey]=np.loadtxt(file_dic[tkey])
        
        JN_reg=util.compute_JN(res_dic[tkey][:,0],res_dic[tkey][:,1],reg_file,
                               base=0,RAbuf=0,debug=0)
        
        
        nrow=res_dic[tkey].shape[0]
        #add weight and jn region
        res_dic[tkey]=np.column_stack([res_dic[tkey],np.ones(nrow),JN_reg])
        
        outfile=file_dic[tkey]+'_withjn.txt'
        np.savetxt(outfile,res_dic[tkey])
        print('written: %s %s'%(tkey,outfile))
        
    return res_dic


#This steps creates new file with jacknife regions
res_dic=assign_jn(datafile,randfile,reg_file)
# Out:
# written: data ../data/LOWZ-all-galaxy.txt_withjn.txt
# written: rand ../data/LOWZ-all-random.txt_withjn.txt

# %% [markdown]
# # To visualize the jn region assigmnet

# %%
def visualize_jn(data_arr,title='data'):
    
    pl.figure(figsize=(10,10))
    JN_reg=data_arr[:,4]
    color_seq=['r','g','b','m','c','y','orange']
    ncol=len(color_seq)
    for jj,jn in enumerate(np.unique(JN_reg)):
        isel=JN_reg==jn
        #print(jj,jn,isel.sum())
        if(jn==-1):
            tcol='k'
        else:
            tcol= color_seq[jj%ncol]
        pl.plot(data_arr[isel,0],data_arr[isel,1],'o',color=tcol)
    
    pl.title(title,fontsize=20)
    
    return

visualize_jn(res_dic['data'],title='data')
visualize_jn(res_dic['rand'],title='rand')

# %% [markdown]
# # Compute the correlation function with jacknife error

# %%
# Now lets get correlation with error using the new file with jn
datafile_jn='../data/LOWZ-all-galaxy.txt_withjn.txt'
randfile_jn='../data/LOWZ-all-random.txt_withjn.txt'

# %%
#datafile='../data/GAMA-G15-galaxy.txt'
#randfile='../data/GAMA-G15-random.txt'
xi_dic=get_xi(datafile_jn,randfile=randfile_jn,rlim=[0,40,0,1],
              nbins=[20,60],sampmode=0,njn=100,pbc=0,los=0,rsd=0
                  ,filetype='polartxt',outtag='LOWZ-jn')
# Out:
# ../CorrelationFunction/Runme_Correlation.py -data ../data/LOWZ-all-galaxy.txt_withjn.txt -rand ../data/LOWZ-all-random.txt_withjn.txt -randfactor 2 -sampmode 0 -samplim 0.000000 40.000000 0.000000 1.000000 -nbins 20 60 -pbc 0 -los 0 -Lbox 250.000000 -outfile tmp/PairCount/LOWZ-jn -RSD 0 -njn 100 -filetype polartxt -nproc 4
# outfile : tmp/PairCount/LOWZ-jn
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# read: ../data/LOWZ-all-galaxy.txt_withjn.txt (317780, 5)
# /home/nc/Desktop/ICTS_ICGC_2024_tutorials/lss-handson/CorrelationFunction/General_FITS_selection.py:82: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   tb=pd.read_table(fname,delim_whitespace=True,comment='#',header=None)
# nrand selected:  635560 635560
# (317780, 5) (635560, 5)
# post: (317780, 5)
#     317780 galaxies from ../data/LOWZ-all-galaxy.txt_withjn.txt
#     635560 randoms from ../data/LOWZ-all-random.txt_withjn.txt
#
# Time:1 sec
#
# Prepared data and random:2 sec
# Updating nhocells to : 175, because ndata_min=317780
#
# Workind on DD (. every 100k points):
#
# Finished DD in 4 sec with 4 process and 317780 317780 particles, max scale    40.0000
#
# Workind on DR (. every 100k points):
#
# Finished DR in 13 sec with 4 process and 317780 635560 particles, max scale    40.0000
#
# Workind on RR (. every 100k points):
#
# Finished RR in 37 sec with 4 process and 635560 635560 particles, max scale    40.0000
#
# Finished job in 37 sec with 4 process and nrand 635560 ,max scale    40.0000
# assuming xitype: auto RRtype=
# RRtype:
# written:  tmp/XI2D/LOWZ-jn-rmu-NJN-100.txt
# outtags:  ['xi0', 'xi2']
# written: tmp/XI02/LOWZ-jn-xi0-rmu-NJN-100.txt
# written: tmp/XI02/LOWZ-jn-xi2-rmu-NJN-100.txt
# ...............

# %%
#pl.plot(xi_dic['xi0'][:,0],np.power(xi_dic['xi0'][:,0],0)*xi_dic['xi0'][:,1],'o-')
pl.errorbar(xi_dic['xi0'][:,0],np.power(xi_dic['xi0'][:,0],2)*xi_dic['xi0'][:,1],
               yerr=np.power(xi_dic['xi0'][:,0],2)*xi_dic['xi0'][:,2],
            marker='o',label='monopole')


#pl.plot(xi_dic['xi2'][:,0],np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,1],'o-')
pl.errorbar(xi_dic['xi2'][:,0],np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,1],
               yerr=np.power(xi_dic['xi2'][:,0],2)*xi_dic['xi2'][:,2],
            marker='o',label='quadrupole')
    

pl.title('LOWZ correlation function with error',fontsize=16)
pl.xlabel('r (Mpc/h)',fontsize=22)
pl.ylabel(r'$r^2 \xi_2(r)$',fontsize=22)
# Out:
# Text(0, 0.5, '$r^2 \\xi_2(r)$')
